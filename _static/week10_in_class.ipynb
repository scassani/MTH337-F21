# %% [markdown]
# ## Week 10

# %% [markdown]
# ## File operations

# %% [markdown]
# `open()`

# %%
f=open('movies.txt','w') # opens a file in writing mode
f.write('Jaws,\n The Avengers')
f.close()

# %%
pwd
# Out:
# '/home/simone/Dropbox/buffalo_teaching/0_MTH337_fall21/in_class'

# %%
f=open('movies.txt','a') # opens the file to append (add) to it
f.write('\nPitch perfect')
# Out:
# 14

# %%
f.write('\nWasabi')
f.close()

# %%
f=open('movies.txt','r') # open a file in read mode
s=f.read() # read the whole file
s
# Out:
# 'Jaws,\n The Avengers\nPitch perfect\nWasabi'

# %%
s1=f.read()
s1
# Out:
# ''

# %%
f.tell()
# Out:
# 40

# %%
f.seek(0)
f.tell()
# Out:
# 0

# %%
f.readline() # reads a single line (up to \n  )
# Out:
# 'Jaws,\n'

# %%
f.readlines() # retunrs a list of lines
# Out:
# [' The Avengers\n', 'Pitch perfect\n', 'Wasabi']

# %%
f.seek(0)
# Out:
# 0

# %%
f.read(10) # read 10 characters
# Out:
# 'Jaws,\n The'

# %%
f.close()

# %%
with open('movies.txt','r') as f:
    s=f.read(11)

# %%
s
# Out:
# 'Jaws,\n The '

# %% [markdown]
# ## String manipulation

# %%
s='somebody once told me the world is gonna roll me'

# %%
for k in s[:10]:
    print(k)
# Out:
# s
# o
# m
# e
# b
# o
# d
# y
#
# o

# %%
s[:10]
# Out:
# 'somebody o'

# %%
s[0]='a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b9bb8144a6a0> in <module>
# ----> 1 s[0]='a'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ## find

# %%
s.find('once')
# Out:
# 9

# %% [markdown]
# ## replace

# %%
s.replace('o','O')
# Out:
# 'sOmebOdy Once tOld me the wOrld is gOnna rOll me'

# %%
s
# Out:
# 'somebody once told me the world is gonna roll me'

# %%
s1=s.replace('o','O')
s1
# Out:
# 'sOmebOdy Once tOld me the wOrld is gOnna rOll me'

# %%
s.replace('once','ONCE')
# Out:
# 'somebody ONCE told me the world is gonna roll me'

# %%
s.replace('me','you')
# Out:
# 'soyoubody once told you the world is gonna roll you'

# %%
s
# Out:
# 'somebody once told me the world is gonna roll me'

# %% [markdown]
# ## split

# %%
s.split()
# Out:
# ['somebody', 'once', 'told', 'me', 'the', 'world', 'is', 'gonna', 'roll', 'me']

# %%
s2='somebody once told me\nthe world is gonna roll me'

# %%
print(s2)
# Out:
# somebody once told me
# the world is gonna roll me

# %%
print(s2.split())
# Out:
# ['somebody', 'once', 'told', 'me', 'the', 'world', 'is', 'gonna', 'roll', 'me']

# %%
s.split('me')
# Out:
# ['so', 'body once told ', ' the world is gonna roll ', '']

# %% [markdown]
# ## join

# %%
mylist=s.split('me')

# %%
'ME'.join(mylist)
# Out:
# 'soMEbody once told ME the world is gonna roll ME'

# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib inline

# %%
plt.plot([1,2,3])
